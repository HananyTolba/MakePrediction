# %%
from gpasdnn.kernels import *
kernel = Linear() + Periodic()*RBF()
names = kernel.recursive_str_list()
names
# Out:
# ['RBF', 'Periodic x RBF']

# %%
kernel.label()
# Out:
# 'RBF + Periodic x RBF'

# %%
import numpy as np
x =  np.linspace(-3,3,500)

y = kernel.simulate(x)

import matplotlib.pyplot as plt 

plt.plot(x,y)
